# %% [markdown]
# ### Data Import and Package Setup

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk import bigrams, trigrams
import json
from pprint import pprint
import os

# %% [markdown]
# ### Initialization

# %%
# load json data
dir_path = os.path.dirname(os.path.realpath(""))
with open(dir_path + '/eecs337-w2019-group19/data/gg2013.json') as f:
    data = json.load(f)

stopWords = set(stopwords.words('english'))
twitterwords = {"http", "rt", "goldenglobes", "golden", "globes", "RT", "Golden", "Globes", "GoldenGlobes"}
stopWords = stopWords.union(twitterwords)
keyword = ['present', 'presents', 'presented', 'presenting', 'presenter', 'presenters', 
           'introduce', 'introducing', 'introduces', 'introduce']

# %% [markdown]
# ### Combined tweets

# %%
def contains(a, b):
    a_set = set(a)
    b_set = set(b)
    if len(a_set.intersection(b_set)) > 0: 
        return True
    else:
        return False   

def tweetTokenContain(dataset, keywords, stopwords):
    tweetnumber = []
    tweetlist = []
    i = 0

    for i in range(len(dataset) - 1):
        tweettextToken = []
        words = word_tokenize(dataset[i]['text'])
        words_clean = [token for token in words if token not in stopwords and token.isalpha()]
        
        if contains(words_clean, keywords) == True:
            tweetnumber.append(i)
            tweetlist.append(words_clean)
        
        i += 1
        
    return([tweetnumber, tweetlist])

# %%
tweet_present_tokenized = tweetTokenContain(data, keyword, stopWords)
tct = tweet_present_tokenized[0]
tweet_present_tokenized_list = tweet_present_tokenized[1]

# %%
def tweetPrint(dataset, tweetnumber):
    return [dataset[i]['text'] for i in tweetnumber]

tweet_present = tweetPrint(data, tct)
len(tweet_present)
# Out:
# 1556

# %%
def bigramsDict(tweetlist):

    common_bigrams = {}
    
    for sentence in tweetlist:
        bigrm_in_tweet = list(bigrams(sentence))
        for bg in bigrm_in_tweet:
            if bg in common_bigrams.keys():
                common_bigrams[bg] += 1
            else:
                common_bigrams[bg] = 1
    
    d_view = [ (v,k) for k,v in common_bigrams.items() ]
    return d_view

common_bigrams_dict = bigramsDict(tweet_present_tokenized_list)

# %% [markdown]
# ### Show results

# %%
def printDictbyCount(dict_view, maximum = 30):
    d_view.sort(reverse=True) # natively sort tuples by first element
    counter = 0
    
    for v,k in d_view:
        pprint("%s: %d" % (k,v))
        counter+=1

        if counter > maximum:
            break

printDictbyCount(common_bigrams_dict)
# Out:
# "('Bill', 'Clinton'): 269"
# "('present', 'award'): 122"
# "('saw', 'present'): 97"
# "('KevalBaxi', 'saw'): 97"
# "('Alyssaeinman', 'KevalBaxi'): 97"
# "('introduces', 'Lincoln'): 59"
# "('Clinton', 'introduces'): 59"
# "('Clinton', 'introduce'): 57"
# "('introducing', 'Lincoln'): 50"
# "('Kristen', 'Wiig'): 48"
# "('Robert', 'Pattinson'): 45"
# "('Mitt', 'Romney'): 45"
# "('Will', 'Ferrell'): 44"
# "('Romney', 'introduce'): 44"
# "('Les', 'Miserables'): 44"
# "('Clinton', 'introducing'): 44"
# "('President', 'Bill'): 43"
# "('win', 'Oscar'): 42"
# "('making', 'impossible'): 42"
# "('impossible', 'win'): 42"
# "('Now', 'Mitt'): 42"
# "('Lincoln', 'making'): 42"
# "('LOLGOP', 'Now'): 42"
# "('introduce', 'Les'): 41"
# "('President', 'Clinton'): 41"
# "('Jodie', 'Foster'): 41"
# "('politicoroger', 'Bill'): 40"
# "('Clinton', 'presenting'): 39"
# "('standing', 'ovation'): 37"
# "('introduce', 'Lincoln'): 35"
# "('award', 'presenting'): 34"

# %%
def checkFullNameFormat(inputTuple2):
    if inputTuple2[0][0].isupper() == True and inputTuple2[1][0].isupper() == True:
        return True
    else:
        return False

# %%
def extractPseudoNames(input_dict, lowbound = 10):

    pseudo_namelist = []
    
    for wordpair in input_dict:
        if wordpair[0] >= lowbound and checkFullNameFormat(wordpair[1]) == True:
            name_like = wordpair[1][0].lower() + " " + wordpair[1][1].lower()
            pseudo_namelist.append(name_like)
        
    return(pseudo_namelist)

# %%
pseudo_namelist = extractPseudoNames(common_bigrams_dict, lowbound = 10)
pseudo_namelist
# Out:
# ['george clooney',
#  'christian bale',
#  'tina fey',
#  'amy poehler',
#  'bradley cooper',
#  'kate hudson',
#  'motion picture',
#  'maggie smith',
#  'cnnshowbiz best',
#  'smith downton',
#  'downton abbey',
#  'abbey she',
#  'les miserables',
#  'robert pattinson',
#  'amy tina',
#  'salma hayek',
#  'aduralde who',
#  'mel gibson',
#  'president bill',
#  'bill clinton',
#  'best picture',
#  'huffpostent bill',
#  'president clinton',
#  'united states',
#  'states bill',
#  'mitt romney',
#  'cnnshowbiz president',
#  'will ferrell',
#  'kristen wiig',
#  'wiig will',
#  'will ferrel',
#  'lolgop now',
#  'now mitt',
#  'ferrell kristen',
#  'president united',
#  'tommy lee',
#  'lee jones',
#  'wow now',
#  'it president',
#  'robert downey',
#  'downey jr',
#  'stallone schwarzenegger',
#  'sylvester stallone',
#  'arnold schwarzenegger',
#  'best foreign',
#  'cecil demille',
#  'jodie foster',
#  'alyssaeinman kevalbaxi',
#  'notbillwalton batman',
#  'wolverine globe',
#  'globe a',
#  'julia roberts']

# %% [markdown]
# ### Main method of understanding sentences

# %%
# Method 1: Co-occurrence of names and keywords
def cooccur_tweets(names, keywordlist):
    tweetnumber = []
    i = 0

    for i in range(len(data) - 1):
        tweetsentence = data[i]['text'].lower()
        for name in names:
            tweetsplit = tweetsentence.split(name)
            if len(tweetsplit) > 1:
                for part in tweetsplit:
                    if len(part) > 1:
                        parttoken = word_tokenize(part)
                        if contains(parttoken, keywordlist) == True:
                            tweetnumber.append(i)
        i += 1
    
    return(tweetnumber)

# Method 2: Appearance of keywords immediately or 1 word after names (Subject + Verb structure)
def subjverb_tweets(names, keywordlist):
    tweetnumber = []
    i = 0

    for i in range(len(data) - 1):
        tweetsentence = data[i]['text'].lower()
        for name in names:
            tweetsplit = tweetsentence.split(name)
            if len(tweetsplit) > 1:
                for part in tweetsplit:
                    if len(part) > 1:
                        parttoken = word_tokenize(part)
                        if len(parttoken) > 1:
                            immediateWords = [parttoken[0], parttoken[1]]
                        else:
                            immediateWords = [parttoken[0]]
                        
                        if contains(immediateWords, keywordlist) == True:
                            tweetnumber.append(i)
        i += 1
    
    return(tweetnumber)

# %%
#coc = cooccur_tweets(pseudo_namelist, keyword)
subv = subjverb_tweets(pseudo_namelist, keyword)

# %%
tweetPrint(data, subv)
# Out:
# ['Bradley Cooper and Kate Hudson present the nominees for Best Supporting Actor in a Motion Picture. :-) #GoldenGlobes',
#  'Bradley Cooper and Kate Hudson present Christoph Waltz with Best Supporting Actor #GoldenGlobes',
#  'Kate Hudson presenting an award, looking AMAZING and knowing it, was just about the sexiest thing ever. #GoldenGlobes',
#  "RT @usweekly: when was the last time downton abby's maggie smith was present in Hollywood to accept an award? #goldenglobes",
#  "RT @usweekly: when was the last time downton abby's maggie smith was present in Hollywood to accept an award? #goldenglobes",
#  "RT @usweekly: when was the last time downton abby's maggie smith was present in Hollywood to accept an award? #goldenglobes",
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  "How sick is it that I didn't even notice Kate Hudson presenting earlier because she came out with Bradley Cooper. True story. #GoldenGlobes",
#  'RT @ADuralde: Who needs writers, when you can just have Salma Hayek introduce with, "Something about the best, eh...."? #goldenglobes',
#  'itd be so much funnier if maggie smith was present but didnt feel like walking up stage to accept her reward. #goldenglobes',
#  'Whoa... President Bill Clinton presenting at the #GoldenGlobes.',
#  'Whoa... President Bill Clinton presenting at the #GoldenGlobes.',
#  'Bill Clinton presenting at the #goldenglobes is a bit random to me...',
#  'Why is Bill Clinton presenting at the #GoldenGlobes? And why did he just get a standing ovation?? Lolol',
#  'NO WAY. Bill Clinton presenting at #goldenglobes',
#  'Bill Clinton presents at the Golden Globes?? #random',
#  'Bill Clinton present @ the #GoldenGlobes....ratings taller than an ackee tree, lol lol',
#  'Someone please tell me why Bill Clinton is presenting at the Golden Globes and why people are giving him a standing ovation. #irrelevant',
#  'Is Bill Clinton really presenting at the Golden Globes? Tell me this isnt a dream.',
#  '...why is Bill Clinton presenting at the  Golden Globes...? Randooomm',
#  'Why is Bill Clinton a presenter right now? #goldenglobes',
#  'Bill Clinton presenting Lincoln, Amy and Tina hosting, this is the best golden globes ever!',
#  'Bill Clinton introducing Lincoln...so fitting #GoldenGlobes',
#  '@brittanyoman Especially missing you right now. Watching Golden Globes, Bill Clinton is presenting and just got a standing ovation 😘',
#  'WOW, Bill Clinton is presenting at the #goldenglobes He just keeps on getting cooler :)',
#  'What?? Bill Clinton presenting at golden globes? How awesome is that? :)',
#  'Spielberg got Bill Clinton to present Lincoln. Very clever. #GoldenGlobes',
#  'AWWW BILL CLINTON S INTRODUCING LINCOLN. THAT IS AWESOME. #GoldenGlobes',
#  'Bill Clinton is presenting at #GoldenGlobes....nothing better to do?! &amp; he got a standing ovation o_O #OnlyInAmerica',
#  'Bill Clinton is presenting an award at the #GoldenGlobes LOL Wut',
#  'Bill Clinton introducing "Lincoln"...brilliant.  #GoldenGlobes',
#  'Bill Clinton is introducing Lincoln. Tea Party faithful everywhere freak out #lols #GoldenGlobes',
#  'getting bill clinton to introduce "Lincoln" is the surest sign that it\'s going to get best picture tonight @goldenglobes',
#  'How cool is that? #President Clinton introduces #Lincoln at the #goldenglobes',
#  'RT @GMA: Bill Clinton introduces "Lincoln" as best picture nominee at #GoldenGlobes',
#  "Bill Clinton is presenting Lincoln, which means tonight's ceremony will end sometime tomorrow morning. #ShowUsYourGlobes #GoldenGlobes",
#  'Wow!  President Clinton presenting Lincoln!  Totally cool.  #GoldenGlobes #PowerofCompromise',
#  'Having Bill Clinton introduce your movie must be one of the coolest things ever #goldenglobes #spielberg',
#  'Former President Clinton introducing Best Picture nominee #Lincoln, nicely done #GoldenGlobes',
#  'Bill Clinton introduces "Lincoln" at #GoldenGlobes, making it impossible for it not to win an Oscar.',
#  'RT @MarlowNYC: Bill Clinton introducing \'Lincoln\' at #GoldenGlobes "In LINCOLN, we see a man more interesting than the legend."',
#  'Bill Clinton introducing the movie Lincoln for Best Picture. What a great show! #goldenglobes',
#  'Bill Clinton introducing #Lincoln...awesome! #goldenglobes',
#  'having bill clinton present lincoln was a classy move, #goldenglobes',
#  'Lincoln gets Bill Clinton to introduce them. Wow. #GoldenGlobes',
#  'Bill Clinton introducing Lincoln is the cockiest Oscar campaigning to date. #BotoxReallySettledInAfterTheDNC #DDL #GoldenGlobes',
#  'Bill Clinton introducing “Lincoln.”  Well-played, #GoldenGlobes.  Well-played.',
#  "Prez Bill Clinton introducing the Lincoln film at the #goldenglobes. That's actually pretty freaking awesome",
#  'Bill Clinton introducing Lincoln? "I know Abraham Lincoln, sir and you are no Abraham Lincoln" (nice intro, though) #GoldenGlobes',
#  'Is it an unfair advantage to have Bill Clinton introduce a nominee?? #GoldenGlobes #LincolnMovie',
#  'Bill Clinton introduces "Lincoln" at Golden Globes. Gotta be a first.',
#  'Oh shit! Bill Clinton presenting at the #GoldenGlobes!',
#  "I bet speaking at the '04 @Cornell graduation was more thrilling for Bill Clinton than presenting @ #goldenglobes . #wishfulthinking",
#  'RT @FilmBuff: How appropriate that Bill Clinton presents Lincoln...kinda love Lena Dunham took a pic of Clinton with her phone. #goldenglobes',
#  'Nice move to have President Clinton introduce "Lincoln" #goldenglobes #love this #movie',
#  'Bill Clinton introducing Lincoln is the coolest part of the golden globes so far #raisethebar',
#  "Everyone get on your feet like you're at the Golden Globes and Bill Clinton's presenting.",
#  "Wow, Bill Clinton introduces Best Picture nominee Lincoln! That's classy! #GoldenGlobes 'That was Hilary Clinton's husband!' - Amy P,",
#  'Bill Clinton introducing Lincoln! Too awesome! #Goldenglobes',
#  'Her: "why is Bill Clinton presenting on this awards show?" Me: "Tell me more about these \'Golden Globes\'"',
#  'RT @AlleyofBooks: Wow, #GoldenGlobes bringing in Bill Clinton to introduce Lincoln. Nice move.',
#  'Presenter of the year goes to President Bill Clinton! #GoldenGlobes',
#  'Presenter of the year goes to President Bill Clinton! #GoldenGlobes',
#  '“@politicoroger Bill Clinton introduces "Lincoln" at #GoldenGlobes, making it impossible for it not to win an Oscar

#  'RT @politicoroger: Bill Clinton introduces "Lincoln" at #GoldenGlobes, making it impossible for it not to win an Oscar.',
#  'Nanananana BATMAN! Christian Bale is presenting now. #GoldenGlobes',
#  'i loved watching will ferrell &amp; kristen wiig present award! They are hilarious! #goldenglobes',
#  'Christian Bale introducing Silver Linings Playbook #GoldenGlobes',
#  "Christian Bale just presented Silver Linings Playbook. I can now die happy :') #GoldenGlobes",
#  'Christian Bale presenting Silver Linings Playbook! Nice! Love him &amp; the movie. #GoldenGlobes',
#  'RT @EWeitzman: They should have asked Tommy Lee Jones to introduce Best Comedy or Musical. #GoldenGlobes',
#  'RT @fgis2bz2pp: “@EWeitzman: They should have asked Tommy Lee Jones to introduce Best Comedy or Musical. #GoldenGlobes”\nGreat idea.',
#  'Golden Globes 2013 BILL CLINTON Presents LINCOLN at 2013 Golden Globes Awards - http://t.co/ZLPGEoMR via @Shareaholic',
#  'Free alcohol, lots of money, famous actors, and attractive young women. How DID the Golden Globes convince Bill Clinton to present? #sarcasm',
#  'I love how when Bill Clinton was introducing an award at the #GoldenGlobes they cut to P. Diddy #pimp #thuglife',
#  'Wait... are Tina Fey and Amy Poehler the presenters?!?! #GoldenGlobes',
#  'PICS: Robert Pattinson presenting onstage at the Golden Globes: PICS: Robert Pattinson presenting onstage at the... http://t.co/X385FmFf',
#  'PICS: Robert Pattinson presenting onstage at the Golden Globes: PICS: Robert Pattinson presenting onstage at the... http://t.co/X385FmFf',
#  'PICS: Robert Pattinson presenting onstage at the Golden Globes: PICS: Robert Pattinson presenting ... http://t.co/79f7eF5k #TwilightSaga',
#  'PICS: Robert Pattinson presenting onstage at the Golden Globes: PICS: Robert Pattinson presenting ... http://t.co/79f7eF5k #TwilightSaga',
#  'PICS: Robert Pattinson presenting onstage at the Golden Globes: PICS: Robert Pattinson pres... http://t.co/gsPuMZem (via @robsessedblog)',
#  "#Google #Hot #Trend Robert Pattinson presents at Golden Globes, Kristen Stewart doesn't join... http://t.co/q21RmG74 #TeamFollowBack GCNews",
#  'And we have a shaky recording of Robert Downey Jr presenting at the Golden Globes. http://t.co/JDK2NGTe #RDJ #video',
#  'And we have a shaky recording of Robert Downey Jr presenting at the Golden Globes. http://t.co/JDK2NGTe #RDJ #video',
#  'GOLDEN GLOBES 2013 BILL CLINTON \nPresents LINCOLN at 2013 Golden Globes Awards.... http://t.co/7jyAIf5z',
#  'RT @rdjfilmguide: And we have a shaky recording of Robert Downey Jr presenting at the Golden Globes. http://t.co/JDK2NGTe #RDJ #video',
#  'RT @rdjfilmguide: And we have a shaky recording of Robert Downey Jr presenting at the Golden Globes. http://t.co/JDK2NGTe #RDJ #video',
#  'RT @PhilstarNews: George Clooney presents the Best Actress in a Motion Picture, Drama to Jessica Chastain for "Zero Dark Thirty" #GoldenGlobes',
#  'The only parts I really liked were the opening monologue and when Will Ferrell and Kristen Wiig presented an award #GoldenGlobes',
#  'Julia Roberts presents Best Motion Picture, Drama to "Argo." #GoldenGlobes',
#  'Julia Roberts just presented that award perfectly #goldenglobes',
#  'Julia Roberts presented Argo with the best picture. That made my night. BECAUSE WHERE IS TINA? #GoldenGlobes',
#  'Two surprises of the night: Julia Roberts presenting, Argo winning for Best Picture. #GoldenGlobes',
#  'Well, my highlight of the past 3 hours was definitely Will Ferrell and Kristen Wiig presenting. Hilarious skit. #GoldenGlobes',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  '“@TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes” LOL @JillianSed might like that ;) 👍❤',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'RT @LindseyMStover: And Julia Roberts presenting. OKAY golden globes. Stop being perfect.',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'RT @VanityFair: In case you stepped out, Mel Gibson just presented Jodie Foster with a stuffed hamster on a silver tray at the #GoldenGlobes.',
#  'Great to see Julia Roberts present the final award of the night! #GoldenGlobes',
#  "RT @MentalityMag: Here's Will Ferrell and Kristen Wiig presenting #BestActress at the #GoldenGlobes... #JenniferLawrence https://t.co/apqTBL0T",
#  'RT @TerriEdda: I wish Christian Bale had presented in his Batman voice. #goldenglobes',
#  'Tina fey and amy poehler best hosts ever! Kristin wiig and will ferrell best presenters ever! #GoldenGlobes',
#  '#GoldenGlobe2013 #goldenglobes It was interesting to see Bill Clinton introduce film, Lincoln.',
#  "#Breaking #Headline Robert Pattinson presents at Golden Globes, Kristen Stewart doesn't join... http://t.co/q21RmG74 #TFB Goo",
#  'Amanda Seyfried &amp; Robert Pattinson Present At Golden Globes ...',
#  'Bill Clinton Presents Lincoln Durin Surprise Golden Globes Appearance http://t.co/N3pOqo1t',
#  'Bill Clinton Presents Lincoln Durin Surprise Golden Globes Appearance RT @DailyBrian @BrianBrownNet @BriansWebWorks http://t.co/Wv4HyJXv',
#  "#Fashion #Style Robert Pattinson presents at Golden Globes, Kristen Stewart doesn't join... http://t.co/GFqIx5I9 #TFW",
#  'Bill Clinton Presents Lincoln Durin Surprise Golden Globes Appearance http://t.co/iAQ1Mh4p RT @BrianBrownNet @DailyBrian @DailyGawk',
#  'Bill Clinton Presents Lincoln Durin Surprise Golden Globes Appearance http://t.co/mbyMf8G2 RT @BrianBrownNet @DailyBrian @RonPaulTeam',
#  'RT @politicoroger: Bill Clinton introduces "Lincoln" at #GoldenGlobes, making it impossible for it not to win an Oscar.']

# %% [markdown]
# ### Test if presenters look right

# %%
presenterData = [data[i] for i in subv]
tweet_presenter_tokenized = tweetTokenContain(presenterData, keyword, stopWords)
presenter_tokenized_list = tweet_presenter_tokenized[1]
pr_common_bigrams = bigramsDict(presenter_tokenized_list)
extractPseudoNames(pr_common_bigrams, lowbound = 10)
# Out:
# ['aduralde who',
#  'salma hayek',
#  'president bill',
#  'bill clinton',
#  'president clinton',
#  'kristen wiig',
#  'wiig will',
#  'will ferrell',
#  'lolgop now',
#  'now mitt',
#  'mitt romney',
#  'les miserables',
#  'ferrell kristen',
#  'spielberg president',
#  'is lincoln',
#  'mel gibson',
#  'robert pattinson',
#  'robert downey',
#  'downey jr',
#  'jodie foster',
#  'christian bale',
#  'pics robert']
